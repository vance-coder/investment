# %%
import tushare as ts

# %%
ts.get_hist_data('600848') #一次性获取全部日k线数据
# Out:
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#              open   high  close    low     volume  price_change  p_change  \
# date
# 2021-12-31  14.75  15.00  14.87  14.74   50224.98          0.05      0.34
# 2021-12-30  14.95  14.96  14.82  14.67   80442.86         -0.13     -0.87
# 2021-12-29  15.23  15.73  14.95  14.94  174957.25          0.35      2.40
# 2021-12-28  14.69  14.72  14.60  14.56   42988.40         -0.07     -0.48
# 2021-12-27  14.80  14.88  14.67  14.63   42263.00         -0.14     -0.94
# ...           ...    ...    ...    ...        ...           ...       ...
# 2019-07-09  30.57  31.41  30.82  30.53   44268.93         -0.23     -0.74
# 2019-07-08  32.26  32.26  31.05  30.87   74332.67         -1.47     -4.52
# 2019-07-05  32.39  32.65  32.52  31.97   39652.54          0.04      0.12
# 2019-07-04  32.50  32.98  32.48  32.18   60690.81          0.30      0.93
# 2019-07-03  32.80  32.80  32.18  31.93   74399.09         -0.67     -2.04
#
# ...

# %%
import baostock as bs
import pandas as pd

# 登陆系统
lg = bs.login()
# 显示登陆返回信息
print('login respond error_code:'+lg.error_code)
print('login respond  error_msg:'+lg.error_msg)


print("")
# Out:
# login success!
# login respond error_code:0
# login respond  error_msg:success

# %%
import baostock as bs
import pandas as pd

#### 登陆系统 ####
lg = bs.login()
# 显示登陆返回信息
print('login respond error_code:'+lg.error_code)
print('login respond  error_msg:'+lg.error_msg)
# Out:
# login success!
# login respond error_code:0
# login respond  error_msg:success

# %%
import numpy as np

np
# Out:
# <module 'numpy' from '/usr/local/lib/python3.9/site-packages/numpy/__init__.py'>

# %%
import akshare as ak

fund_portfolio_hold_em_df = ak.fund_portfolio_hold_em(symbol="014130", date="2022")
print(fund_portfolio_hold_em_df)
# Out:
#       序号    股票代码  股票名称  占净值比例    持股数     持仓市值              季度
# 0      1  600570  恒生电子   7.98  48.74  1972.06  2022年4季度股票投资明细
# 1      2  002230  科大讯飞   7.37  55.50  1822.07  2022年4季度股票投资明细
# 2      3  002410   广联达   7.21  29.73  1782.09  2022年4季度股票投资明细
# 3      4  600588  用友网络   6.33  64.71  1564.04  2022年4季度股票投资明细
# 4      5  688111  金山办公   5.91   5.52  1459.93  2022年4季度股票投资明细
# ..   ...     ...   ...    ...    ...      ...             ...
# 243  244  688337  普源精电   0.05   0.23    13.98  2022年1季度股票投资明细
# 244  245  301097  天益医疗   0.04   0.22    11.72  2022年1季度股票投资明细
# 245  246  301151  冠龙节能   0.04   0.37    11.40  2022年1季度股票投资明细
# 246  247  688331  荣昌生物   0.04   0.29    11.29  2022年1季度股票投资明细
# 247  248  301268   铭利达   0.04   0.38    10.69  2022年1季度股票投资明细
#
# [248 rows x 7 columns]

# %%
fund_portfolio_hold_em_df.head(120)
# Out:
#       序号    股票代码  股票名称  占净值比例    持股数     持仓市值              季度
# 0      1  600570  恒生电子   7.98  48.74  1972.06  2022年4季度股票投资明细
# 1      2  002230  科大讯飞   7.37  55.50  1822.07  2022年4季度股票投资明细
# 2      3  002410   广联达   7.21  29.73  1782.09  2022年4季度股票投资明细
# 3      4  600588  用友网络   6.33  64.71  1564.04  2022年4季度股票投资明细
# 4      5  688111  金山办公   5.91   5.52  1459.93  2022年4季度股票投资明细
# ..   ...     ...   ...    ...    ...      ...             ...
# 115  116  301349  信德新材   0.00   0.00     0.34  2022年4季度股票投资明细
# 116  117  301309   万得凯   0.00   0.01     0.34  2022年4季度股票投资明细
# 117  118  301318   维海德   0.00   0.01     0.29  2022年4季度股票投资明细
# 118  119  600570  恒生电子   8.46  52.32  1773.16  2022年3季度股票投资明细
# 119  120  002410   广联达   7.10  32.61  1487.95  2022年3季度股票投资明细
#
# [120 rows x 7 columns]

# %%
import akshare as ak

fund_open_fund_rank_em_df = ak.fund_open_fund_rank_em(symbol="全部")
print(fund_open_fund_rank_em_df)
# Out:
#           序号    基金代码                      基金简称          日期    单位净值    累计净值  \
# 0          1  005844               东方人工智能主题混合A  2023-04-07  1.1663  1.1663
# 1          2  017811               东方人工智能主题混合C  2023-04-07  1.1664  1.1664
# 2          3  005628                 汇安趋势动力股票A  2023-04-07  1.5229  1.5229
# 3          4  005629                 汇安趋势动力股票C  2023-04-07  1.4816  1.4816
# 4          5  005819                 国泰优势行业混合A  2023-04-07  2.0041  2.0041
# ...      ...     ...                       ...         ...     ...     ...
# 11607  11608  018263     海富通稳健养老目标一年持有混合(FOF)Y  2023-04-04  1.2251  1.2251
# 11608  11609  018222                 工银优质精选混合C  2023-04-07  3.3320  3.3320
# 11609  11610  016660  招商和惠养老2045五年持有混合发起式(FOF)  2023-04-04  1.0114  1.0114
# 11610  11611  018259                永赢竞争力精选混合C  2023-04-07  1.3848  1.3848
# 11611  11612  018264    海富通平衡养老目标三年持有期混合(FOF)Y  2023-04-04  1.1467  1.1467
#
# ...

# %%
import akshare as ak

fund_name_em_df = ak.fund_name_em()
print(fund_name_em_df)
# Out:
#          基金代码                  拼音缩写                  基金简称     基金类型  \
# 0      000001                HXCZHH                华夏成长混合   混合型-灵活
# 1      000002                HXCZHH            华夏成长混合(后端)   混合型-灵活
# 2      000003              ZHKZZZQA              中海可转债债券A  债券型-可转债
# 3      000004              ZHKZZZQC              中海可转债债券C  债券型-可转债
# 4      000005            JSZQXYDQZQ            嘉实增强信用定期债券   债券型-长债
# ...       ...                   ...                   ...      ...
# 18571  970205  XZZGJQLXXZLLGYCYQZQC  兴证资管金麒麟兴享增利六个月持有期债券C  债券型-混合债
# 18572  970206         ZJYSLHYNCYHHC         中金优势领航一年持有混合C   混合型-偏股
# 18573  970207               GXRFZQC               国信睿丰债券C  债券型-混合债
# 18574  970208      GXJDZHSGYCYHHFOF    国信经典组合三个月持有混合(FOF)      FOF
# 18575  980003           TPYLGYGDCYZ           太平洋六个月滚动持有债   债券型-长债
#
#                                                     拼音全称
# 0                                  HUAXIACHENGZHANGHUNHE
# ...

# %%
import akshare as ak

fund_portfolio_industry_allocation_em_df = ak.fund_portfolio_industry_allocation_em(symbol="014130", date="2022")
print(fund_portfolio_industry_allocation_em_df)
# Out:
#     序号             行业类别  占净值比例            市值        截止时间
# 0    1  信息传输、软件和信息技术服务业  73.48  18158.841934  2022-12-31
# 1    2              制造业  18.99   4693.643796  2022-12-31
# 2    3         租赁和商务服务业   0.92    227.360000  2022-12-31
# 3    4          卫生和社会工作   0.01      2.469852  2022-12-31
# 4    5       科学研究和技术服务业   0.01      2.203212  2022-12-31
# 5    6    水利、环境和公共设施管理业   0.01      1.652750  2022-12-31
# 6    7        文化、体育和娱乐业   0.00      0.560450  2022-12-31
# 7    8  信息传输、软件和信息技术服务业  62.62  13133.518760  2022-09-30
# 8    9              制造业  30.90   6480.927170  2022-09-30
# 9   10         租赁和商务服务业   0.72    151.004400  2022-09-30
# 10  11       科学研究和技术服务业   0.04      7.383860  2022-09-30
# 11  12    水利、环境和公共设施管理业   0.02      4.033153  2022-09-30
# 12  13          卫生和社会工作   0.01      1.356054  2022-09-30
# 13  14        文化、体育和娱乐业   0.00      0.546700  2022-09-30
# 14  15  信息传输、软件和信息技术服务业  61.79  13974.644696  2022-06-30
# ...

# %%
20*(1.25**10)
# Out:
# 186.2645149230957

# %%
# Out:
# 5.0
