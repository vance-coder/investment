# %%
import time
from datetime import datetime

import akshare as ak

# %%
"""
version 1:

参数化
统计连续复合上引线的最大时间段

获取N天的行情、统计每天的上引线情况，复合条件为True
然后获取N天内上引线情况？

每个票的板块、概念信息
存redis吧

如何自动适配参数！
"""
# Out:
# '\nversion 1:\n\n统计连续复合上引线的最大时间段\n\n每个票的板块、概念信息\n存redis吧\n\n如何自动适配参数！\n\n'

# %%
import akshare as ak
import json
import pandas as pd
from datetime import datetime

def read_data():
    with open('update.json') as fp:
        return json.loads(fp.read())
    
def update_data(data):
    with open('concept.json', 'w+') as fp:
        fp.write(json.dumps(data))

data = {}

df_list = []

stock_board_concept_name_ths_df = ak.stock_board_concept_name_ths()

for idx, row in stock_board_concept_name_ths_df.iterrows():
    # key: 日期、概念名称、成分股数量、网址、代码
    row_dct = row.to_dict()
    cc_code = row_dct['代码']
    concept = row_dct['概念名称']
    
    stock_board_cons_ths_df = ak.stock_board_cons_ths(symbol=cc_code)
    stock_board_cons_ths_df['概念'] = concept
    stock_board_cons_ths_df = stock_board_cons_ths_df.drop('序号', axis=1)
    df_list.append(stock_board_cons_ths_df)
    time.sleep(2)
    # print(row_dct)
    if idx > 1000:
        break

ndf = pd.concat(df_list)

def combine(ser):
    if ser.name == '概念':
        return ','.join(ser)
    return ser.tolist()[0]

ndf = ndf.groupby('代码').aggregate(combine)
ndf.to_csv('concept.csv')
ndf.head(10)

# %%
import akshare as ak


def get_trade(symbol):
    """
    获取行业信息
    :param symbol:
    :return:
    """
    df = ak.stock_individual_info_em(symbol=symbol)
    print(df)
    dct = dict(zip(df['item'], df['value']))
    return dct['行业'], dct['股票简称']

get_trade('003004')
# Out:
#    item         value
# 0   总市值  2425737600.0
# 1  流通市值  1000307022.0
# 2    行业         计算机设备
# 3  上市时间      20201126
# 4  股票代码        003004
# 5  股票简称          声迅股份
# 6   总股本    81840000.0
# 7   流通股    33748550.0
# ('计算机设备', '声迅股份')

# %%
from pyecharts import options as opts
from pyecharts.globals import CurrentConfig, OnlineHostType
from pyecharts.charts import Kline, Line, Grid
from pyecharts.globals import CurrentConfig, NotebookType
from IPython.display import display
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_LAB
CurrentConfig.ONLINE_HOST = OnlineHostType.NOTEBOOK_HOST

data = [
    [2320.26, 2320.26, 2287.3, 2362.94],
    [2300, 2291.3, 2288.26, 2308.38],
    [2295.35, 2346.5, 2295.35, 2345.92],
    [2347.22, 2358.98, 2337.35, 2363.8],
    [2360.75, 2382.48, 2347.89, 2383.76],
]

def plot_kline(df, symbol):
    date_list = df['日期'].to_list()
    ndf = df[['开盘', '收盘', '最低', '最高']]
    data = ndf.values.tolist()
    
    area, name = get_trade(symbol)
    
    kline = (
    Kline()
    .add_xaxis(date_list)
    .add_yaxis(name, data)
    .set_global_opts(
        yaxis_opts=opts.AxisOpts(
            is_scale=True,
            splitarea_opts=opts.SplitAreaOpts(
                is_show=True, areastyle_opts=opts.AreaStyleOpts(opacity=1)
            ),
        ),
        xaxis_opts=opts.AxisOpts(is_scale=True),
        datazoom_opts=[opts.DataZoomOpts(type_="inside")],
        title_opts=opts.TitleOpts(title=symbol),
    ))
    
    line = (
        Line()
        .add_xaxis(xaxis_data=date_list)
        .add_yaxis(
            series_name="MA5",
            y_axis=df['ma_5'].tolist(),
            is_smooth=True,
            is_hover_animation=False,
            linestyle_opts=opts.LineStyleOpts(width=1.5, opacity=0.8, color="#4B4453"),
            label_opts=opts.LabelOpts(is_show=False),
        )
        .add_yaxis(
            series_name="MA10",
            y_axis=df['ma_10'].tolist(),
            is_smooth=True,
            is_hover_animation=False,
            linestyle_opts=opts.LineStyleOpts(width=1.5, opacity=0.8, color="#FF8C00"),
            label_opts=opts.LabelOpts(is_show=False),
        )
        .add_yaxis(
            series_name="MA20",
            y_axis=df['ma_20'].tolist(),
            is_smooth=True,
            is_hover_animation=False,
            linestyle_opts=opts.LineStyleOpts(width=1.5, opacity=0.8, color="#4B0082"),
            label_opts=opts.LabelOpts(is_show=False),
        )
        .set_global_opts(xaxis_opts=opts.AxisOpts(type_="category"))
    )
    
    # Kline And Line
    overlap_kline_line = kline.overlap(line)

    # Grid Overlap + Bar
    grid_chart = Grid(
        init_opts=opts.InitOpts(
            width="900px",
            height="800px",
            animation_opts=opts.AnimationOpts(animation=False),
        )
    )
    grid_chart.add(
        overlap_kline_line,
        grid_opts=opts.GridOpts(pos_left="10%", pos_right="8%", height="50%"),
    )

    grid_chart.load_javascript()
    return grid_chart.render_notebook()
    

df = pd.read_csv(os.path.join(folder, '003004.csv'))
display(plot_kline(df, '003004'))
# Out:
#    item         value
# 0   总市值  2425737600.0
# 1  流通市值  1000307022.0
# 2    行业         计算机设备
# 3  上市时间      20201126
# 4  股票代码        003004
# 5  股票简称          声迅股份
# 6   总股本    81840000.0
# 7   流通股    33748550.0
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="eac57bcbf9864930851d4b5dcc7147b0" class="chart-container" style="width:900px; height:800px;"></div>
#     <script>
#         var chart_eac57bcbf9864930851d4b5dcc7147b0 = echarts.init(
#             document.getElementById('eac57bcbf9864930851d4b5dcc7147b0'), 'white', {renderer: 'canvas'});
#         var option_eac57bcbf9864930851d4b5dcc7147b0 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "candlestick",
#             "name": "\u58f0\u8fc5\u80a1\u4efd",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "data": [
#                 [
#                     25.78,
#                     25.89,
#                     25.7,
#                     26.34
#                 ],
#                 [
#                     26.1,
#                     25.18,
#                     24.87,
#                     26.48
#                 ],
#                 [
#                     24.77,
#                     25.22,
#                     24.58,
#                     25.49
#                 ],
#                 [
#                     25.0,
#                     26.0,
#                     24.82,
#                     26.4
#                 ],
#                 [
#                     25.76,
#                     26.92,
#                     25.71,
#                     26.95
#                 ],
#                 [
#                     29.61,
#                     29.61,
#                     29.61,
#                     29.61
#                 ],
#                 [
#                     32.57,
#                     32.57,
#                     32.57,
#                     32.57
#                 ],
#                 [
#                     35.6,
#                     35.83,
#                     32.0,
#                     35.83
#                 ],
#                 [
#                     36.0,
#                     37.18,
#                     34.44,
#                     39.41
#                 ],
#                 [
#                     34.95,
#                     40.9,
#                     33.46,
#                     40.9
#                 ],
#                 [
#                     39.99,
#                     36.81,
#                     36.81,
#                     40.04
#                 ],
#                 [
#                     33.16,
#                     33.13,
#                     33.13,
#                     34.49
#                 ],
#                 [
#                     29.86,
#                     29.82,
#                     29.82,
#                     30.82
#                 ],
#                 [
#                     29.0,
#                     29.0,
#                     28.59,
#                     29.28
#                 ],
#                 [
#                     28.76,
#                     28.76,
#                     28.3,
#                     28.88
#                 ],
#                 [
#                     28.77,
#                     30.85,
#                     28.73,
#                     31.58
#                 ],
#                 [
#                     29.98,
#                     29.55,
#                     29.5,
#                     30.53
#                 ],
#                 [
#                     29.56,
#                     29.08,
#                     28.53,
#                     29.64
#                 ],
#                 [
#                     28.79,
#                     29.61,
#                     28.61,
#                     29.7
#                 ],
#                 [
#                     29.33,
#                     29.1,
#                     28.8,
#                     29.45
#                 ],
#                 [
#                     29.0,
#                     27.13,
#                     27.05,
#                     29.0
#                 ],
#                 [
#                     27.13,
#                     27.58,
#                     27.0,
#                     27.62
#                 ],
#                 [
#                     27.7,
#                     27.5,
#                     27.06,
#                     27.9
#                 ],
#                 [
#                     27.65,
#                     27.16,
#                     27.03,
#                     27.75
#                 ],
#                 [
#                     27.16,
#                     27.2,
#                     27.0,
#                     27.49
#                 ],
#                 [
#                     27.28,
#                     28.18,
#                     26.7,
#                     28.4
#                 ],
#                 [
#                     27.78,
#                     26.55,
#                     26.4,
#                     27.8
#                 ],
#                 [
#                     26.23,
#                     26.8,
#                     26.23,
#                     27.3
#                 ],
#                 [
#                     26.59,
#                     27.5,
#                     26.5,
#                     27.51
#                 ],
#                 [
#                     27.38,
#                     29.0,
#                     26.65,
#                     29.59
#                 ],
#                 [
#                     28.81,
#                     28.04,
#                     27.5,
#                     28.81
#                 ],
#                 [
#                     27.7,
#                     29.75,
#                     27.41,
#                     30.2
#                 ],
#                 [
#                     29.19,
#                     30.27,
#                     29.0,
#                     30.5
#                 ],
#                 [
#                     29.94,
#                     29.15,
#                     29.0,
#                     29.95
#                 ],
#                 [
#                     29.24,
#                     28.69,
#                     27.33,
#                     29.24
#                 ],
#                 [
#                     28.3,
#                     28.0,
#                     27.86,
#                     28.58
#                 ],
#                 [
#                     26.51,
#                     26.21,
#                     25.5,
#                     27.33
#                 ],
#                 [
#                     26.2,
#                     27.41,
#                     25.62,
#                     27.72
#                 ],
#                 [
#                     27.54,
#                     30.15,
#                     26.82,
#                     30.15
#                 ],
#                 [
#                     31.11,
#                     30.24,
#                     29.54,
#                     32.49
#                 ],
#                 [
#                     30.25,
#                     29.03,
#                     29.03,
#                     30.46
#                 ],
#                 [
#                     29.68,
#                     30.5,
#                     29.21,
#                     30.67
#                 ],
#                 [
#                     30.26,
#                     29.94,
#                     29.09,
#                     30.4
#                 ],
#                 [
#                     30.01,
#                     29.08,
#                     29.03,
#                     30.18
#                 ],
#                 [
#                     29.08,
#                     28.94,
#                     28.65,
#                     29.53
#                 ],
#                 [
#                     28.92,
#                     27.58,
#                     27.48,
#                     29.18
#                 ],
#                 [
#                     27.8,
#                     28.22,

# %% [markdown]
# ### 频繁上影线异动筛选

# %%
import os

count = 0
times_of_unusual = 5
folder = 'daily_data/'

files = os.listdir(folder)
for f in files:
    try:
        if not f.endswith('.csv'):
            continue
            
        code = f.split('.')[0]
        df = pd.read_csv(os.path.join(folder, f), encoding='utf-8')
        
        # 10日均线在20日均线上、最新股价在60日均线上
        # 不能偏离60日线太远
        last_row_data = df.iloc[-1].to_dict()
        last_cond1 = last_row_data['ma_10'] >= last_row_data['ma_20']*0.98
        last_cond2 = last_row_data['收盘'] >= last_row_data['ma_60']*0.98
        last_cond3 = (last_row_data['收盘'] - last_row_data['ma_60'])/last_row_data['收盘']*100 < 16
        if not (last_cond1 and last_cond2 and last_cond3):
            continue

        # 条件筛选
        # 换手率大于 2.5, 小于25 【真实的换手率其实需要排除掉一些实控人的资金，再计算的，这里不算严格】
        cond1 = (df['换手率'] > 1.5) & (df['换手率'] < 25)

        # 振幅大于 6.5
        cond3 = df['振幅'] > 6.5

        # (-2 <= 涨跌幅 <= 5.5) [收在-2到5.5之间]
        cond4 = (-2 < df['涨跌幅']) & (df['涨跌幅'] <= 5.5)

        # 上影线是实体的0.8倍以上 【放宽条件，后续进行人工筛选】
        # cond5 = df['upper_lead'] >= df['len_of_entity'] * 0.8
        cond5 = df['upper_lead'] >= 2.8

        # 下引线小于2.3
        cond6 = df['lower_lead'] < 2.5

        df['flag'] = cond1 & cond3 & cond4 & cond5 & cond6
        sdf = df[df['flag']]
        if not sdf.empty and len(sdf) >= 6:
            first_row = ndf[ndf.index.isin([code])].iloc[0]
            first_dct = first_row.to_dict()
            print(code, first_dct['名称'], f'流通市值：{first_dct["流通市值"]}')
            print('距离60日线点位:', (last_row_data['收盘'] - last_row_data['ma_60'])/last_row_data['收盘']*100)
            print(f'异动次数：{len(sdf)}')
            print(first_dct['概念'])
            print('\n'.join(sdf['日期']))
            print('_'*10)

        count += 1

        # if count > 1000:
            # break
    except Exception as e:
        print(f)
        print(e)


"""
股价新高的不要，欧晶科技
反例：
宝明科技
"""
# Out:
# 002389 航天彩虹 流通市值：210.19亿
# 距离60日线点位: 1.1560069144338887
# 异动次数：8
# 国企改革,央企国企改革,共同富裕示范区,新材料概念,军民融合,MiniLED,标普道琼斯A股,柔性屏,MSCI概念,深股通,光伏概念,融资融券,无人机,军工
# 2022-09-14
# 2022-09-16
# 2022-09-22
# 2022-09-23
# 2022-10-13
# 2022-10-20
# 2022-11-01
# 2022-11-16
# __________
# 600706 曲江文旅 流通市值：34.04亿
# 距离60日线点位: 10.793472845042372
# 异动次数：8
# 国企改革,露营经济,体育产业,一带一路,数字经济
# 2022-11-02
# 2022-11-04
# 2022-11-09
# 2022-11-15
# 2022-12-13
# 2022-12-30
# 2023-03-08
# 2023-03-21
# __________
# 603186 华正新材 流通市值：45.12亿
# 距离60日线点位: 3.791064388961892
# 异动次数：6
# 先进封装（Chiplet）,PCB概念,冷链物流,芯片概念,5G,锂电池
# 2023-02-03
# 2023-02-06
# 2023-02-08
# 2023-02-14
# 2023-02-21
# 2023-03-15
# __________
# 002799 环球印务 流通市值：34.12亿
# 距离60日线点位: -0.9763681592039802
# 异动次数：8
# ChatGPT概念,国企改革,抖音概念,虚拟数字人,新冠检测,快手概念,区块链,大数据
# 2022-10-26
# 2022-11-02
# 2022-12-02
# 2022-12-22
# 2022-12-23
# 2022-12-29
# 2022-12-30
# 2023-03-23
# __________
# 002564 天沃科技 流通市值：46.85亿
# 距离60日线点位: 2.521135265700491
# 异动次数：7
# 国企改革,上海国企改革,超超临界发电,碳中和,氢能源,煤化工,军民融合,一带一路,光伏概念,融资融券,高端装备,风电,光热发电,特高压,军工,核电
# 2022-11-09
# 2022-11-28
# 2022-12-02
# 2022-12-05
# 2022-12-14
# 2023-03-09
# 2023-03-28
# __________
# 002559 亚威股份 流通市值：39.05亿
# 距离60日线点位: 2.00000000000002
# 异动次数：7
# 比亚迪概念,智能制造,工业母机,光刻胶,机器人概念,3D打印,工业4.0,工业互联网,OLED,边缘计算,机器视觉,芯片概念,光伏概念,高端装备,军工
# 2022-10-19
# 2022-10-20
# 2022-10-25
# 2022-10-28
# 2022-10-31
# 2022-11-17
# 2022-11-18
# __________
# 000428 华天酒店 流通市值：54.61亿
# 距离60日线点位: 1.6239316239316242
# 异动次数：8
# 国企改革,股权转让,预制菜,职业教育,深股通,融资融券
# 2022-10-18
# 2022-11-02
# 2022-11-03
# 2022-11-04
# 2022-11