# %%
import akshare as ak

df = ak.fund_open_fund_info_em(fund="008087")
df
# Out:
#            净值日期    单位净值  日增长率
# 0    2019-12-10  1.0000  0.00
# 1    2019-12-13  1.0001  0.00
# 2    2019-12-20  0.9954  0.00
# 3    2019-12-27  0.9859  0.00
# 4    2019-12-31  0.9982  0.00
# ..          ...     ...   ...
# 776  2023-03-31  0.9809  1.44
# 777  2023-04-03  1.0156  3.54
# 778  2023-04-04  1.0266  1.08
# 779  2023-04-06  1.0485  2.13
# 780  2023-04-07  1.0570  0.81
#
# [781 rows x 3 columns]

# %%
from pyecharts import options as opts
from pyecharts.globals import CurrentConfig, OnlineHostType
from pyecharts.charts import Kline, Line, Grid
from pyecharts.globals import CurrentConfig, NotebookType
from IPython.display import display
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_LAB
CurrentConfig.ONLINE_HOST = OnlineHostType.NOTEBOOK_HOST

c = (
    Line()
    .add_xaxis(df['净值日期'].tolist())
    .add_yaxis("单位净值", df['单位净值'].tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title="Line-基本示例"))
)

c.load_javascript()
c.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="d24662243b4a45daaad766d92d922574" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_d24662243b4a45daaad766d92d922574 = echarts.init(
#             document.getElementById('d24662243b4a45daaad766d92d922574'), 'white', {renderer: 'canvas'});
#         var option_d24662243b4a45daaad766d92d922574 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u5355\u4f4d\u51c0\u503c",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2019-12-10",
#                     1.0
#                 ],
#                 [
#                     "2019-12-13",
#                     1.0001
#                 ],
#                 [
#                     "2019-12-20",
#                     0.9954
#                 ],
#                 [
#                     "2019-12-27",
#                     0.9859
#                 ],
#                 [
#                     "2019-12-31",
#                     0.9982
#                 ],
#                 [
#                     "2020-01-03",
#                     1.0281
#                 ],
#                 [
#                     "2020-01-10",
#                     1.0523
#                 ],
#                 [
#                     "2020-01-17",
#                     1.0757
#                 ],
#                 [
#                     "2020-01-23",
#                     1.0959
#                 ],
#                 [
#                     "2020-02-07",
#                     1.0716
#                 ],
#                 [
#                     "2020-02-10",
#                     1.0715
#                 ],
#                 [
#                     "2020-02-11",
#                     1.0921
#                 ],
#                 [
#                     "2020-02-12",
#                     1.106
#                 ],
#                 [
#                     "2020-02-13",
#                     1.1069
#                 ],
#                 [
#                     "2020-02-14",
#                     1.1193
#                 ],
#                 [
#                     "2020-02-17",
#                     1.1707
#                 ],
#                 [
#                     "2020-02-18",
#                     1.1908
#                 ],
#                 [
#                     "2020-02-19",
#                     1.1835
#                 ],
#                 [
#                     "2020-02-20",
#                     1.2224
#                 ],
#                 [
#                     "2020-02-21",
#                     1.2561
#                 ],
#                 [
#                     "2020-02-24",
#                     1.3158
#                 ],
#                 [
#                     "2020-02-25",
#                     1.353
#                 ],
#                 [
#                     "2020-02-26",
#                     1.2823
#                 ],
#                 [
#                     "2020-02-27",
#                     1.2695
#                 ],
#                 [
#                     "2020-02-28",
#                     1.2117
#                 ],
#                 [
#                     "2020-03-02",
#                     1.2625
#                 ],
#                 [
#                     "2020-03-03",
#                     1.259
#                 ],
#                 [
#                     "2020-03-04",
#                     1.2232
#                 ],
#                 [
#                     "2020-03-05",
#                     1.2287
#                 ],
#                 [
#                     "2020-03-06",
#                     1.215
#                 ],
#                 [
#                     "2020-03-09",
#                     1.1587
#                 ],
#                 [
#                     "2020-03-10",
#                     1.2295
#                 ],
#                 [
#                     "2020-03-11",
#                     1.196
#                 ],
#                 [
#                     "2020-03-12",
#                     1.1813
#                 ],
#                 [
#                     "2020-03-13",
#                     1.1809
#                 ],
#                 [
#                     "2020-03-16",
#                     1.0849
#                 ],
#                 [
#                     "2020-03-17",
#                     1.0692
#                 ],
#                 [
#                     "2020-03-18",
#                     1.0428
#                 ],
#                 [
#                     "2020-03-19",
#                     1.075
#                 ],
#                 [
#                     "2020-03-20",
#                     1.0735
#                 ],
#                 [
#                     "2020-03-23",
#                     1.0109
#                 ],
#                 [
#                     "2020-03-24",
#                     1.0316
#                 ],
#                 [
#                     "2020-03-25",
#                     1.0687
#                 ],
#                 [
#                     "2020-03-26",
#                     1.0435
#                 ],
#                 [
#                     "2020-03-27",
#                     1.031
#                 ],
#                 [
#                     "2020-03-30",
#                     1.0063
#                 ],
#                 [
#                     "2020-03-31",
#                     0.9997
#                 ],
#                 [
#                     "2020-04-01",
#                     1.0034
#                 ],
#                 [
#                     "2020-04-02",
#                     1.0577
#                 ],
#                 [
#                     "2020-04-03",
#                     1.0396
#                 ],
#                 [
#                     "2020-04-07",
#                     1.0676
#                 ],
#                 [
#                     "2020-04-08",
#                     1.0749
#                 ],
#                 [
#                     "2020-04-09",
#                     1.0706
#                 ],
#                 [
#                     "2020-04-10",
#                     1.0309
#                 ],
#                 [
#                     "2020-04-13",
#                     1.006
#                 ],
#                 [
#                     "2020-04-14",
#                     1.0387
#                 ],
#                 [
#                     "2020-04-15",
#                     1.0432
#                 ],
#                 [
#                     "2020-04-16",
#                     1.0453
#                 ],
#                 [
#                     "2020-04-17",
#                     1.0647
#                 ],
#                 [
#                     "2020-04-20",
#                     1.0772
#                 ],
#                 [
#                     "2020-04-21",
#                     1.0654
#                 ],
#                 [
#                     "2020-04-22",
#                     1.0676
#                 ],
#                 [
#                     "2020-04-23",
#                     1.0487
#                 ],
#                 [
#                     "2020-04-24",
#                     1.0303
#                 ],
#                 [
#                     "2020-04-27",
#                     1.0379
#                 ],
#                 [
#                     "2020-04-28",
#                     1.0594
#                 ],
#                 [
#                     "2020-04-29",
#                     1.0606
